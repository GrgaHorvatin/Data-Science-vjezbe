# %% [markdown]
# # 4th auditory exercise
#
# ## Following the 4th lecture, "The first look at the data."
#
# **For all additional questions contact Liljana Puškar (liljana.puskar@fer.hr)**
#
# We will use the `titanic` data set you used in the previous auditory exercises.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("titanic.csv",index_col = 0) #load the data set, with the first column as column names

# %% [markdown]
# ## Initial data overview

# %%
df.head() #show the first five rows of the dataframe
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
with pd.option_context("display.max_rows", None, 'display.max_columns', None):
    display(df)
    
    #display options for easier viewing of dataframes
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
df.describe(include='all') #show the descriptive statistics of each column
# Out:
#           Survived      Pclass                     Name   Sex         Age  \
# count   891.000000  891.000000                      891   891  714.000000
# unique         NaN         NaN                      891     2         NaN
# top            NaN         NaN  Braund, Mr. Owen Harris  male         NaN
# freq           NaN         NaN                        1   577         NaN
# mean      0.383838    2.308642                      NaN   NaN   29.699118
# std       0.486592    0.836071                      NaN   NaN   14.526497
# min       0.000000    1.000000                      NaN   NaN    0.420000
# 25%       0.000000    2.000000                      NaN   NaN   20.125000
# 50%       0.000000    3.000000                      NaN   NaN   28.000000
# 75%       1.000000    3.000000                      NaN   NaN   38.000000
# max       1.000000    3.000000                      NaN   NaN   80.000000
#
#              SibSp       Parch  Ticket        Fare    Cabin Embarked
# ...

# %%
df.columns.values #show the names of all columns
# Out:
# array(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
df.info() #show info about the columns, count and data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df['Age'].astype #show type of data for a column
# Out:
# dtype('float64')

# %%
df['Age'].mean() #caluclate and show the mean of a column
# Out:
# 29.69911764705882

# %%
df['Age'].median() #caluclate and show the median of a column
# Out:
# 28.0

# %%
df['Age'].mode() #caluclate and show the mode of a column
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
df['Age'].min() #caluclate and show the minimum value in a column
# Out:
# 0.42

# %%
df['Age'].max() #caluclate and show the maximum value in a column
# Out:
# 80.0

# %%
df['Age'].std() #caluclate and show the standard deviation of a column
# Out:
# 14.526497332334042

# %%
df['Age'].std(ddof=0) #caluclate and show the standard deviation of a column with a zero degree of freedom
# Out:
# 14.516321150817316

# %%
df['Age'].var() #caluclate and show the variation of a column
# Out:
# 211.01912474630802

# %%
df['Age'].var(ddof=0) #caluclate and show the vatiation of a column with a zero degree of freedom
# Out:
# 210.72357975366614

# %%
df['Age'].std() / df.Age.mean() * 100 #caluclate and show the coefficient of variation
# Out:
# 48.91221855465675

# %%
plt.hist(df.Age)
plt.axvline(df.Age.mean(), color='k', linestyle='dashed', linewidth=2)
plt.axvline(df.Age.median(), color='red', linestyle='dashed', linewidth=2)

plt.show()

#draw a histogram with the mean and median lines shown in different colors

# %%
df.groupby('Sex').describe().transpose() #show the desriptive statistics of the column 'Sex' grouped by the unique vaules of column, use transpose to pivot the table
# Out:
# Sex                 female        male
# Survived count  314.000000  577.000000
#          mean     0.742038    0.188908
#          std      0.438211    0.391775
#          min      0.000000    0.000000
#          25%      0.000000    0.000000
#          50%      1.000000    0.000000
#          75%      1.000000    0.000000
#          max      1.000000    1.000000
# Pclass   count  314.000000  577.000000
#          mean     2.159236    2.389948
#          std      0.857290    0.813580
#          min      1.000000    1.000000
#          25%      1.000000    2.000000
#          50%      2.000000    3.000000
#          75%      3.000000    3.000000
#          max      3.000000    3.000000
# Age      count  261.000000  453.000000
#          mean    27.915709   30.726645
#          std     14.110146   14.678201
#          min      0.750000    0.420000
#          25%     18.000000   21.000000
#          50%     27.000000   29.000000
#          75%     37.000000   39.000000
# ...

# %%
Female = df.query('Age == 30') #add all rows where 'Age' is 30 to a new dataframe called Female

# %%
pclass_30 = Female.query('Pclass == 3') #add all rows from the dataframe Female, where 'Pclass' is 3, to a new dataframe called pclass_30

# %%
pclass_30 #show pclass_30
# Out:
#              Survived  Pclass  \
# PassengerId
# 80                  1       3
# 158                 0       3
# 245                 0       3
# 254                 0       3
# 287                 1       3
# 366                 0       3
# 489                 0       3
# 535                 0       3
# 607                 0       3
# 799                 0       3
# 800                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 80                                    Dowdell, Miss. Elizabeth  female  30.0
# 158                                            Corn, Mr. Harry    male  30.0
# 245                                       Attalah, Mr. Sleiman    male  30.0
# 254                                   Lobb, Mr. William Arthur    male  30.0
# 287                                    de Mulder, Mr. Theodore    male  30.0
# 366                             Adahl, Mr. Mauritz Nils Martin    male  30.0
# ...

# %% [markdown]
# ## z-test
#
# **Null hypothesis:** Socio-economic class of people did not affect the survival rate.
#
# **Alternative hypothesis:** People's socio-economic class affected their survival rate.

# %%
from statsmodels.stats.weightstats import ztest as ztest

# %%
FirstClass = df.query('Pclass == 1')
ThirdClass = df.query('Pclass == 3')

FirstClass_sample = FirstClass.sample(n=100, random_state=1) #random_state pamti koji sample je izabrani
ThirdClass_sample = ThirdClass.sample(n=100, random_state=1)

# %%
df.groupby('Pclass')['Survived'].mean() #show the mean of Survived for each value in Pclass
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
FirstClass_sample['Survived'].hist()
# Out:
# <Axes: >

# %%
Survived_normal = np.array([np.mean(df[df["Pclass"]==1].sample(20)["Survived"].values) for i in range(100)])
FirstClass_sample['Survived_normal'] = Survived_normal

Survived_normal_t = np.array([np.mean(df[df["Pclass"]==3].sample(20)["Survived"].values) for i in range(100)])
ThirdClass_sample['Survived_normal'] = Survived_normal_t

#samples 20 passengers from the first class, calculates the survival rate for each sample, 
#and stores these survival rates in the "Survived_normal" column of the FirstClass_sample dataframe
# same for third class

# %%
FirstClass_sample['Survived_normal'].hist() #histogram of the survival rates in first class
# Out:
# <Axes: >

# %% [markdown]
# ## Two Sample Z-Test

# %%
ztest(FirstClass_sample['Survived_normal'], ThirdClass_sample['Survived'], value=0)
# Out:
# (8.750957227104438, 2.1155055222669653e-18)

# %% [markdown]
# ## One Sample Z-test

# %%
ztest(FirstClass_sample['Survived_normal'], value=0)
# Out:
# (57.6754089712418, 0.0)

# %%
ztest(ThirdClass_sample['Survived_normal'], value=0)
# Out:
# (27.219373205655792, 3.831152934228705e-163)

# %% [markdown]
# ## Decide which test to use
#
# **Two basic categories:**
#
# 1. **Parametric:** assumes that the sample data come from a population that can be adequately modeled by a probability distribution that has a fixed set of parameters
#
# 2. **Non-parametric:** does not assume an explicit (finite parametric) mathematical form for the distribution when modeling data. However, it may make some assumptions about that distribution, such as continuity or symmetry.

# %%
from scipy import stats

# %% [markdown]
# ## Homogeneity

# %%
stats.levene(FirstClass_sample['Survived_normal'],ThirdClass_sample['Survived_normal'])
# Out:
# LeveneResult(statistic=1.2059199707655786, pvalue=0.27347526158961877)

# %% [markdown]
# ## T-test

# %%
stats.ttest_ind(FirstClass_sample['Survived_normal'],ThirdClass_sample['Survived_normal'])
# Out:
# Ttest_indResult(statistic=26.001212897247875, pvalue=9.232569647968544e-66)

# %% [markdown]
# ## Analysis of Variance Test (ANOVA)

# %% [markdown]
# Tests whether the means of two or more independent samples are significantly different.
#
# **Assumptions**
#
# 1. Observations in each sample are independent and identically distributed (iid).
# 2. Observations in each sample are normally distributed.
# 3. Observations in each sample have the same variance.
#
# **Interpretation**
#
# 1. H0: the means of the samples are equal.
# 2. H1: one or more of the means of the samples are unequal.

# %%
from scipy.stats import f_oneway
stat, p = f_oneway(FirstClass_sample['Survived_normal'],ThirdClass_sample['Survived_normal'])
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably the same distribution')
else:
	print('Probably different distributions')
# Out:
# stat=676.063, p=0.000
# Probably different distributions

# %% [markdown]
# ## Shapiro-Wilk Test
#
# **Tests whether a data sample has a Gaussian distribution.**
#
# **Assumptions:**
#
# Observations in each sample are independent and identically distributed (iid).
#
# 1. H0: the sample has a Gaussian distribution.
# 2. H1: the sample does not have a Gaussian distribution.

# %%
from scipy.stats import shapiro

# %%
stat, p = shapiro(FirstClass_sample['Survived_normal'])

# %%
print('stat=%.3f, p=%.3f' % (stat, p))
# Out:
# stat=0.946, p=0.000

# %%
if p > 0.05:
	print('Probably Gaussian')
else:
	print('Probably not Gaussian')
# Out:
# Probably not Gaussian

# %% [markdown]
# ## Mann-Whitney U Test

# %% [markdown]
# Tests whether the distributions of two independent samples are equal or not.
#
# Assumptions
#
# Observations in each sample are independent and identically distributed (iid).
# Observations in each sample can be ranked.
# Interpretation
#
# H0: the distributions of both samples are equal.
# H1: the distributions of both samples are not equal.

# %%
from scipy.stats import mannwhitneyu
stat, p = mannwhitneyu(FirstClass_sample['Survived_normal'],ThirdClass_sample['Survived_normal'])
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably the same distribution')
else:
	print('Probably different distributions')
# Out:
# stat=9950.500, p=0.000
# Probably different distributions

# %% [markdown]
# ## Wilcoxon Signed-Rank Test

# %% [markdown]
# **Tests whether the distributions of two paired samples are equal or not.**
#
# **Assumptions:**
#
# 1. Observations in each sample are independent and identically distributed (iid).
# 2. Observations in each sample can be ranked.
# 3. Observations across each sample are paired.
#
# **Interpretation**
#
# 1. H0: the distributions of both samples are equal.
# 2. H1: the distributions of both samples are not equal.

# %%
from scipy.stats import wilcoxon
stat, p = wilcoxon(FirstClass_sample['Survived_normal'],ThirdClass_sample['Survived_normal'])
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably the same distribution')
else:
	print('Probably different distributions')
# Out:
# stat=0.000, p=0.000
# Probably different distributions

# %% [markdown]
# ## Kruskal-Wallis H Test

# %% [markdown]
# Tests whether the distributions of two or more independent samples are equal or not.
#
# **Assumptions**
#
# 1. Observations in each sample are independent and identically distributed (iid).
# 2. Observations in each sample can be ranked.
#
# **Interpretation**
#
# 1. H0: the distributions of all samples are equal.
# 2. H1: the distributions of one or more samples are not equal.

# %%
from scipy.stats import kruskal
stat, p = kruskal(FirstClass_sample['Survived_normal'],ThirdClass_sample['Survived_normal'])
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably the same distribution')
else:
	print('Probably different distributions')
# Out:
# stat=147.337, p=0.000
# Probably different distributions
